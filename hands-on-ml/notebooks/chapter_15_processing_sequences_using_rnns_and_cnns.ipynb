# %% [markdown]
# # Setup

# %%
import numpy as np

import tensorflow as tf
from tensorflow.keras import metrics, losses, layers, models, optimizers, callbacks, activations

# %% [markdown]
# # Forecasting a Time Series

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10)) # wave 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # wave 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5) # noise
    return series[..., np.newaxis].astype(np.float32)

# %%
# Create the training, validation and test set

n_steps = 50
series = generate_time_series(10000, n_steps + 1)
x_train, y_train = series[:7000, :n_steps], series[:7000, -1]
x_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
x_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %% [markdown]
# ## Baseline Metrics

# %%
# Naive Forecasting
y_pred = x_valid[:, -1]
np.mean(losses.mean_squared_error(y_valid, y_pred))
# Out:
# 0.02084235

# %%
# Use FNN to forecast the next value

model = models.Sequential([
    layers.Flatten(input_shape=[50, 1]),
    layers.Dense(1)
])

params = {
    'loss' : 'mse',
    'metrics' : 'mse',
    'optimizer' : 'adam'
}

model.compile(**params)

model.fit(x_train, y_train,
          validation_data=[x_valid, y_valid],
          epochs=20)
# Out:
# Epoch 1/20
# 219/219 [==============================] - 1s 2ms/step - loss: 0.1247 - mse: 0.1247 - val_loss: 0.0546 - val_mse: 0.0546
# Epoch 2/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0423 - mse: 0.0423 - val_loss: 0.0306 - val_mse: 0.0306
# Epoch 3/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0263 - mse: 0.0263 - val_loss: 0.0211 - val_mse: 0.0211
# Epoch 4/20
# 219/219 [==============================] - 1s 4ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 5/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 6/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 7/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 8/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 9/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 10/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 11/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 12/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 13/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 14/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 15/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 16/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 17/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 18/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 19/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 20/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0041 - val_mse: 0.0041

# %%
print(f'The MSE of this model is {model.evaluate(x_test, y_test)[1]}')
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0044 - mse: 0.0044
# The MSE of this model is 0.004371064715087414

# %% [markdown]
# ## Implementing a Simple RNN

# %%
model = models.Sequential([
    layers.SimpleRNN(1, input_shape=[None, 1])
])

model.compile(**params)

model.fit(x_train, y_train,
          validation_data=[x_valid, y_valid],
          epochs=20)
# Out:
# Epoch 1/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.2273 - mse: 0.2273 - val_loss: 0.1508 - val_mse: 0.1508
# Epoch 2/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.1053 - mse: 0.1053 - val_loss: 0.0781 - val_mse: 0.0781
# Epoch 3/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0689 - mse: 0.0689 - val_loss: 0.0615 - val_mse: 0.0615
# Epoch 4/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0571 - mse: 0.0571 - val_loss: 0.0523 - val_mse: 0.0523
# Epoch 5/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0453 - val_mse: 0.0453
# Epoch 6/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0426 - mse: 0.0426 - val_loss: 0.0398 - val_mse: 0.0398
# Epoch 7/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0377 - mse: 0.0377 - val_loss: 0.0355 - val_mse: 0.0355
# Epoch 8/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0337 - mse: 0.0337 - val_loss: 0.0319 - val_mse: 0.0319
# Epoch 9/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0304 - mse: 0.0304 - val_loss: 0.0290 - val_mse: 0.0290
# Epoch 10/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0277 - mse: 0.0277 - val_loss: 0.0266 - val_mse: 0.0266
# Epoch 11/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0254 - mse: 0.0254 - val_loss: 0.0244 - val_mse: 0.0244
# Epoch 12/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0226 - val_mse: 0.0226
# Epoch 13/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.0210 - val_mse: 0.0210
# Epoch 14/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 15/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 16/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0173 - val_mse: 0.0173
# Epoch 17/20
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0168 - mse: 0.0168 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 18/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 19/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 20/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0141 - val_mse: 0.0141

# %%
print(f'The MSE of this model is {model.evaluate(x_test, y_test)[1]}')
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0146 - mse: 0.0146
# The MSE of this model is 0.014572584070265293

# %% [markdown]
# ## Deep RNNs

# %%
model = models.Sequential([
    layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    layers.SimpleRNN(10, return_sequences=True),
    layers.SimpleRNN(1)
])

model.compile(**params)

model.fit(x_train, y_train,
          validation_data=[x_valid, y_valid],
          epochs=20)
# Out:
# Epoch 1/20
# 219/219 [==============================] - 7s 22ms/step - loss: 0.0310 - mse: 0.0310 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 2/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 3/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 4/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 5/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 6/20
# 219/219 [==============================] - 4s 21ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 7/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 8/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 9/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 10/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 11/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 12/20
# 219/219 [==============================] - 4s 21ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 13/20
# 219/219 [==============================] - 4s 21ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 14/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 15/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 16/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 17/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 18/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 19/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 20/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0034 - val_mse: 0.0034

# %%
print(f'The MSE of this model is {model.evaluate(x_test, y_test)[1]}')
# Out:
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0034 - mse: 0.0034
# The MSE of this model is 0.0033664132934063673

# %%
model = models.Sequential([
    layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    layers.SimpleRNN(10),
    layers.Dense(1)
])

model.compile(**params)

model.fit(x_train, y_train,
          validation_data=[x_valid, y_valid],
          epochs=20)
# Out:
# Epoch 1/20
# 219/219 [==============================] - 5s 16ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 2/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 3/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 4/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 5/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 6/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 7/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 8/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 9/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 10/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 11/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 12/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 13/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 14/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 15/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 16/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 17/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 18/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 19/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 20/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0030 - val_mse: 0.0030

# %%
print(f'The MSE of this model is {model.evaluate(x_test, y_test)[1]}')
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0032 - mse: 0.0032
# The MSE of this model is 0.003151234006509185

# %% [markdown]
# ## Forecasting Several Time Steps Ahead

# %%
# Predict one value at a time

series = generate_time_series(1, n_steps + 10)
x_new, y_new = series[:, :n_steps], series[:, n_steps:]
x = x_new
for step_ahead in range(10):
    y_pred_one = model.predict(x[:, step_ahead:])[:, np.newaxis, :]
    x = np.concatenate([x, y_pred_one], axis=1)

y_pred = x[:, n_steps:]

# %%
# Predict the 10 values at once
series = generate_time_series(10000, n_steps + 10)
x_train, y_train = series[:7000, :n_steps], series[:7000, -10:, 0]
x_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -10:, 0]
x_test, y_test = series[9000:, :n_steps], series[9000:, -10, 0]

# Create, compile and train the model 
model = models.Sequential([
    layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    layers.SimpleRNN(20),
    layers.Dense(10)
])

model.compile(**params)

model.fit(x_train, y_train,
          validation_data=[x_valid, y_valid],
          epochs=20)
# Out:
# Epoch 1/20
# 219/219 [==============================] - 4s 15ms/step - loss: 0.0783 - mse: 0.0783 - val_loss: 0.0390 - val_mse: 0.0390
# Epoch 2/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0280 - mse: 0.0280 - val_loss: 0.0210 - val_mse: 0.0210
# Epoch 3/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 4/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 5/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 6/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 7/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 8/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 9/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 10/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 11/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 12/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 13/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 14/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 15/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 16/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 17/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 18/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 19/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 20/20
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0084 - val_mse: 0.0084

# %%
y_pred = model.predict(x_new)
y_pred
# Out:
# array([[-0.4852456 , -0.365886  , -0.22739744, -0.06450187,  0.11762518,
#          0.26355815,  0.36882114,  0.4553286 ,  0.4889334 ,  0.48952588]],
#       dtype=float32)

# %%
# Convert the previous snippet to sequence-to-sequence
y = np.empty((10000, n_steps, 10))
for step_ahead in range(1, 10 + 1):
    y[:, :, step_ahead - 1] = series[:, step_ahead:step_ahead + n_steps, 0]
y_train = y[:7000]
y_valid = y[7000:9000]
y_test = y[9000:]

# %%
model = models.Sequential([
    layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    layers.SimpleRNN(20, return_sequences=True),
    layers.TimeDistributed(layers.Dense(10))
])

model.compile(**params)

model.fit(x_train, y_train,
          validation_data=[x_valid, y_valid],
          epochs=20)
# Out:
# Epoch 1/20
# 219/219 [==============================] - 5s 16ms/step - loss: 0.0726 - mse: 0.0726 - val_loss: 0.0469 - val_mse: 0.0469
# Epoch 2/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0434 - mse: 0.0434 - val_loss: 0.0400 - val_mse: 0.0400
# Epoch 3/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0386 - mse: 0.0386 - val_loss: 0.0370 - val_mse: 0.0370
# Epoch 4/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0361 - mse: 0.0361 - val_loss: 0.0349 - val_mse: 0.0349
# Epoch 5/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0353 - mse: 0.0353 - val_loss: 0.0342 - val_mse: 0.0342
# Epoch 6/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0340 - mse: 0.0340 - val_loss: 0.0342 - val_mse: 0.0342
# Epoch 7/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0334 - mse: 0.0334 - val_loss: 0.0328 - val_mse: 0.0328
# Epoch 8/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0325 - mse: 0.0325 - val_loss: 0.0318 - val_mse: 0.0318
# Epoch 9/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0320 - mse: 0.0320 - val_loss: 0.0312 - val_mse: 0.0312
# Epoch 10/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0313 - mse: 0.0313 - val_loss: 0.0308 - val_mse: 0.0308
# Epoch 11/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0306 - mse: 0.0306 - val_loss: 0.0302 - val_mse: 0.0302
# Epoch 12/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0298 - mse: 0.0298 - val_loss: 0.0298 - val_mse: 0.0298
# Epoch 13/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0292 - mse: 0.0292 - val_loss: 0.0288 - val_mse: 0.0288
# Epoch 14/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0287 - mse: 0.0287 - val_loss: 0.0289 - val_mse: 0.0289
# Epoch 15/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0280 - mse: 0.0280 - val_loss: 0.0276 - val_mse: 0.0276
# Epoch 16/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0275 - mse: 0.0275 - val_loss: 0.0273 - val_mse: 0.0273
# Epoch 17/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0272 - mse: 0.0272 - val_loss: 0.0267 - val_mse: 0.0267
# Epoch 18/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0264 - mse: 0.0264 - val_loss: 0.0259 - val_mse: 0.0259
# Epoch 19/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0257 - mse: 0.0257 - val_loss: 0.0257 - val_mse: 0.0257
# Epoch 20/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0250 - mse: 0.0250 - val_loss: 0.0245 - val_mse: 0.0245

# %% [markdown]
# # Handling Long Sequences

# %% [markdown]
# ## Fighting The Unstable Gradients Problem

# %%
# Create a custom SimpleRNN cell that applies LayerNormalization
class LNSimpleRNNCell(layers.Layer):
    
    def __init__(self, units, activation='tanh', **kwargs):
        super().__init__(**kwargs)
        self.state_size = units
        self.output_size = units
        self.simple_rnn_cell = layers.SimpleRNNCell(units, activation=None)
        self.layer_norm = layers.LayerNormalization()
        self.activation = activations.get(activation)
    
    def call(self, inputs, states):
        outputs, new_states = self.simple_rnn_cell(inputs, states)
        norm_outputs = self.activation(self.layer_norm(outputs))
        return norm_outputs, [norm_outputs]

# %%
# Implementing this custom cell requires using a keras.layers.RNN layer
model = models.Sequential([
    layers.RNN(LNSimpleRNNCell(20), return_sequences=True, input_shape=[None, 1]),
    layers.RNN(LNSimpleRNNCell(20), return_sequences=True),
    layers.TimeDistributed(layers.Dense(10))
])

model.compile(**params)

model.fit(x_train, y_train,
          validation_data=[x_valid, y_valid],
          epochs=20,
          verbose=0)

print(f'The MSE of the model is {model.evaluate(x_test, y_test, verbose=0)[1]}')
# Out:
# The MSE of the model is 0.026506725698709488

# %% [markdown]
# ## Tackling the Short-Term Memory Problem

# %% [markdown]
# ### LSTM Cells

# %%
model = models.Sequential([
    layers.LSTM(20, return_sequences=True, input_shape=[None, 1]),
    layers.LSTM(20, return_sequences=True),
    layers.Dense(10)
])

model.compile(**params)
model.fit(x_train, y_train,
          validation_data=[x_valid, y_valid],
          epochs=20)
# Out:
# Epoch 1/20
# 219/219 [==============================] - 11s 35ms/step - loss: 0.0776 - mse: 0.0776 - val_loss: 0.0513 - val_mse: 0.0513
# Epoch 2/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0444 - mse: 0.0444 - val_loss: 0.0384 - val_mse: 0.0384
# Epoch 3/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0360 - mse: 0.0360 - val_loss: 0.0341 - val_mse: 0.0341
# Epoch 4/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0324 - mse: 0.0324 - val_loss: 0.0313 - val_mse: 0.0313
# Epoch 5/20
# 219/219 [==============================] - 7s 32ms/step - loss: 0.0304 - mse: 0.0304 - val_loss: 0.0295 - val_mse: 0.0295
# Epoch 6/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0290 - mse: 0.0290 - val_loss: 0.0286 - val_mse: 0.0286
# Epoch 7/20
# 219/219 [==============================] - 7s 32ms/step - loss: 0.0280 - mse: 0.0280 - val_loss: 0.0277 - val_mse: 0.0277
# Epoch 8/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0274 - mse: 0.0274 - val_loss: 0.0269 - val_mse: 0.0269
# Epoch 9/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0267 - mse: 0.0267 - val_loss: 0.0265 - val_mse: 0.0265
# Epoch 10/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0263 - mse: 0.0263 - val_loss: 0.0264 - val_mse: 0.0264
# Epoch 11/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0258 - mse: 0.0258 - val_loss: 0.0258 - val_mse: 0.0258
# Epoch 12/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0255 - mse: 0.0255 - val_loss: 0.0252 - val_mse: 0.0252
# Epoch 13/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0252 - mse: 0.0252 - val_loss: 0.0251 - val_mse: 0.0251
# Epoch 14/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0249 - mse: 0.0249 - val_loss: 0.0247 - val_mse: 0.0247
# Epoch 15/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0245 - mse: 0.0245 - val_loss: 0.0242 - val_mse: 0.0242
# Epoch 16/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0242 - mse: 0.0242 - val_loss: 0.0243 - val_mse: 0.0243
# Epoch 17/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0239 - mse: 0.0239 - val_loss: 0.0237 - val_mse: 0.0237
# Epoch 18/20
# 219/219 [==============================] - 7s 30ms/step - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0242 - val_mse: 0.0242
# Epoch 19/20
# 219/219 [==============================] - 7s 30ms/step - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0233 - val_mse: 0.0233
# Epoch 20/20
# 219/219 [==============================] - 7s 30ms/step - loss: 0.0228 - mse: 0.0228 - val_loss: 0.0227 - val_mse: 0.0227

# %%
evaluation = model.evaluate(x_test, y_test, verbose=0)
print(f'The MSE of the model is {evaluation[1]}')
# Out:
# The MSE of the model is 0.02304089069366455

# %% [markdown]
# ### Using 1D convolutional layers to process sequences

# %%
def last_time_step_mse(y_true, y_pred):
    return metrics.mean_squared_error(y_true[:-1], y_pred[:, -1])

params = {
    'loss' : 'mse',
    'metrics' : [last_time_step_mse],
    'optimizer' : 'adam'
}

# %%
model = models.Sequential([
    layers.Conv1D(filters=20,
                  kernel_size=4,
                  strides=2,
                  padding='valid',
                  input_shape=[None, 1]),
    layers.GRU(20, return_sequences=True),
    layers.GRU(20, return_sequences=True),
    layers.Dense(10)
])

# %% [markdown]
# ### WaveNet

# %%
model = models.Sequential([
    layers.InputLayer(input_shape=[None, 1])
])

for rate in (1, 2, 4, 8) * 2:
    model.add(layers.Conv1D(filters=20, 
                            kernel_size=2, 
                            padding='causal',
                            activation='relu',
                            dilation_rate=rate))
model.add(layers.Conv1D(filters=10, kernel_size=1))

# %% [markdown]
# # Exercises

# %% [markdown]
# 1. Can you think of a few applications for a sequence-to-sequence RNN? What
# about a sequence-to-vector RNN, and a vector-to-sequence RNN?
#
# > One application to sequence-to-sequence would be to enter text that describes the audio we want to generate, and the output to be a track that reproduces the audio we required. For sequence-to-vector would be to provide a song and have a NN that determines the genre of the song. Finally, one vector-to-sequence would be providing an image and obtaining the description of the image.

# %% [markdown]
# 2. How many dimensions must the inputs of an RNN layer have? What does each
# dimension represent? What about its outputs?
#
# > The input of an RNN needs to have 3 dimensions: *batch size*, *time steps*, and *dimensionality*. The dimensionality determines the number of features of the input. The output depends on the task: it may be a vector, or a sequence. Depending on the task, the output may have 1 or more dimensions.

# %% [markdown]
# 3. If you want to build a deep sequence-to-sequence RNN, which RNN layers
# should have return_sequences=True? What about a sequence-to-vector RNN?
#
# > In the first example, all the RNN cells should have ```return_sequences=True```. If we want to have a sequence-to-vector RNN, we should have ```return_sequences=True``` in all the layers except for the last RNN Cell.

# %% [markdown]
# 4. Suppose you have a daily univariate time series, and you want to forecast the next seven days. Which RNN architecture should you use?
#
# > In order to forecast the next seven days, the architecture should be several RNN cells with ```return_sequences=True``` except for the top layer, and an additional ```Dense``` layer with 7 neurons, and no activation. This would be a sequence-to-vector. Alternatively, we could train the model to have a sequence of the next 7 days as target, and have all the layers with the hyperparameter ```return_sequences=True``` and this would be a sequence-to-sequence.

# %% [markdown]
# 5. What are the main difficulties when training RNNs? How can you handle them?
#
# > The two main difficulties are the unstable gradients and the limited memory of the network. The first can be approached by using smaller learning rates, saturating activation functions, LayerNormalization or dropout. The second, can be addressed by using another RNN cells such as the ```LSTM``` (Long-Short Term Memory) and ```GRU``` (Gated Recurrent Unit) layers that improves the long term memory of the network.

# %% [markdown]
# 6. Can you sketch the LSTM cell’s architecture?
#
# >

# %% [markdown]
# 7. Why would you want to use 1D convolutional layers in an RNN?
#
# > Using 1D convolutional layers allows to apply filters to the input, by reducing their dimensionality and helping the network to have a better memory for long sequences.

# %% [markdown]
# 8. Which neural network architecture could you use to classify videos?
#
# > The architecture to use may be a sequence-to-vector, where each frame can be seen as a time step, and process this into a embedding to then pass the embedding to a ```Dense``` layer with softmax as activation function. The loss function would be ```cross-entropy``` .
